# %% [markdown]
# ### Explore Then Implement

# %%
import sys
import os

BASE_DIR = os.getcwd()  # Gets current working directory

sys.path.append(os.path.abspath(os.path.join(BASE_DIR, "..")))

from frontend.transformation import (
    transform_google_locations, transform_google_trend, 
    transform_twitter_hashflags, transform_twitter_locations, transform_twitter_trend
)

# %%
import numpy as np

# %%
# Assuming transform_twitter_trend() gives you a DataFrame
df = transform_twitter_trend()

# Drop duplicates based on the 'trend' column
df = df.drop_duplicates(subset=['trend'])

# Remove rows where 'meta_description' is missing or empty
df = df[df['meta_description'].notna() & (df['meta_description'] != '')]

# Function to extract the numeric part of the 'meta_description' and handle 'K' and 'M'
def extract_numeric(meta_desc):
    # Remove commas in case there are any in large numbers (e.g., 9,969)
    meta_desc = meta_desc.replace(',', '')
    
    # Try to extract the number from the meta description, ignoring non-numeric characters
    number_str = ''.join(filter(str.isdigit, meta_desc))
    
    # If a number is found, check if there's a suffix (K or M)
    if number_str:
        number = int(number_str)
        
        # Handle 'K' (thousand) and 'M' (million)
        if 'K' in meta_desc.upper():  # 'K' for thousands
            number *= 1000
        elif 'M' in meta_desc.upper():  # 'M' for millions
            number *= 1000000
        return number
    else:
        return np.nan  # Return NaN if no numeric value is found

# Apply the function to create a new column 'meta_description_numeric' for sorting
df['meta_description_numeric'] = df['meta_description'].apply(extract_numeric)

# Sort by the numeric part of the 'meta_description' in descending order
df_sorted = df.sort_values('meta_description_numeric', ascending=False)

# Select only the columns you want to display
df_sorted = df_sorted[['trend', 'meta_description', 'domain_context']]

# Check if the 'meta_description_numeric' column exists before dropping it
if 'meta_description_numeric' in df_sorted.columns:
    df_sorted = df_sorted.drop(columns=['meta_description_numeric'])

# Display the final sorted DataFrame
print(df_sorted)
# Out:
# /Users/maria/Documents/NowTrending/frontend/transformation.py:96: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#                   trend                                   meta_description  \
# 13142             Trump                                        2.76M posts
# 15112     BREAKING NEWS                                        1.81M posts
# 5306               DOGE                                        1.48M posts
# 2350              USAID                                        1.41M posts
# 2358               Musk                                        1.36M posts
# ...                 ...                                                ...
# 48759          Berlinie                                        1,002 posts
# 6749             Filiks                                        1,001 posts
# 45367     #GenerativeAI                                        1,001 posts
# 2601   #DiversiónBetfun                              Promoted by betfun.ok
# 52198        #BirOluruz  Promoted by T.C. Çevre, Şehircilik ve İklim Dğ...
#
#              domain_context
# 13142              Politics
# 15112                  News
# 5306   Business and finance
# 2350    Trending in Ukraine
# 2358    Trending in Ukraine
# ...                     ...
# 48759    Trending in Poland
# 6749     Trending in Poland
# 45367    Trending in Norway
# 2601
# 52198
#
# [1517 rows x 3 columns]

# %%
def twitter_top_ten():
    # Assuming transform_twitter_trend() gives you a DataFrame
    df = transform_twitter_trend()

    # Drop duplicates based on the 'trend' column
    df = df.drop_duplicates(subset=['trend'])

    # Remove rows where 'meta_description' is missing or empty
    df = df[df['meta_description'].notna() & (df['meta_description'] != '')]

    # Function to extract the numeric part of the 'meta_description' and handle 'K' and 'M'
    def extract_numeric(meta_desc):
        # Remove commas in case there are any in large numbers (e.g., 9,969)
        meta_desc = meta_desc.replace(',', '')
        
        # Try to extract the number from the meta description, ignoring non-numeric characters
        number_str = ''.join(filter(str.isdigit, meta_desc))
        
        # If a number is found, check if there's a suffix (K or M)
        if number_str:
            number = int(number_str)
            
            # Handle 'K' (thousand) and 'M' (million)
            if 'K' in meta_desc.upper():  # 'K' for thousands
                number *= 1000
            elif 'M' in meta_desc.upper():  # 'M' for millions
                number *= 1000000
            return number
        else:
            return np.nan  # Return NaN if no numeric value is found

    # Apply the function to create a new column 'meta_description_numeric' for sorting
    df['meta_description_numeric'] = df['meta_description'].apply(extract_numeric)

    # Sort by the numeric part of the 'meta_description' in descending order
    df_sorted = df.sort_values('meta_description_numeric', ascending=False)

    # Select only the columns you want to display
    df_sorted = df_sorted[['trend', 'meta_description', 'domain_context']]

    # Check if the 'meta_description_numeric' column exists before dropping it
    if 'meta_description_numeric' in df_sorted.columns:
        df_sorted = df_sorted.drop(columns=['meta_description_numeric'])

    # Output the top 10 rows without index
    return df_sorted.head(10)

# %%
import pandas as pd

# %%
def twitter_trends_location():
    # Transform the location and trend DataFrames
    df_loc = transform_twitter_locations()
    df_trend = transform_twitter_trend()

    # Merge the DataFrames on 'location_id' using an inner join
    merged_df = pd.merge(df_loc, df_trend, on='location_id', how='inner')

    # Select and order the desired columns
    df_sorted = merged_df[['country', 'trend', 'domain_context', 'url']]

    return df_sorted

# %%
df = transform_twitter_trend()
df
# Out:
# /Users/maria/Documents/NowTrending/frontend/transformation.py:96: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#           id           trend  position meta_description  \
# 0          1  Fantastic Four         0
# 1          2       Netanyahu         1
# 2          3    Jessica Alba         2      2,054 posts
# 3          4            OSHA         3      37.9K posts
# 4          5    Waffle House         4      7,327 posts
# ...      ...             ...       ...              ...
# 56827  56828  Methylene Blue        14      5,248 posts
# 56828  56829           Deebo        15      2,195 posts
# 56829  56830      Drake Bell        16      4,866 posts
# 56830  56831  James Harrison        17      3,513 posts
# 56831  56832       Spartacus        19      4,129 posts
#
#                   domain_context  \
# 0                  Entertainment
# 1                       Politics
# 2                  Entertainment
# 3                       Politics
# 4              Chain restaurants
# ...                          ...
# 56827  Trending in United States
# 56828                     Sports
# 56829              Entertainment
# 56830                     Sports
# 56831                   Politics
#
#                                                      url  \
# 0      twitter://search/?query=%22Fantastic+Four%22&s...
# 1      twitter://search/?query=Netanyahu&src=trend_cl...
# 2      twitter://search/?query=%22Jessica+Alba%22&src...
# 3      twitter://search/?query=OSHA&src=trend_click&p...
# 4      twitter://search/?query=%22Waffle+House%22&src...
# ...                                                  ...
# 56827  twitter://search/?query=%22Methylene+Blue%22&s...
# 56828  twitter://search/?query=Deebo&src=trend_click&...
# 56829  twitter://search/?query=%22Drake+Bell%22&src=t...
# 56830  twitter://search/?query=%22James+Harrison%22&s...
# 56831  twitter://search/?query=Spartacus&src=trend_cl...
#
#                     last_updated           location_id
# 0     2025-02-04 22:48:44.048739  -7293673535050703919
# 1     2025-02-04 22:48:44.048739  -7293673535050703919
# 2     2025-02-04 22:48:44.048739  -7293673535050703919
# 3     2025-02-04 22:48:44.048739  -7293673535050703919
# 4     2025-02-04 22:48:44.048739  -7293673535050703919
# ...                          ...                   ...
# 56827 2025-02-06 01:17:40.900583  -2999473465018429484
# 56828 2025-02-06 01:17:40.900583  -2999473465018429484
# 56829 2025-02-06 01:17:40.900583  -2999473465018429484
# 56830 2025-02-06 01:17:40.900583  -2999473465018429484
# 56831 2025-02-06 01:17:40.900583  -2999473465018429484
#
# [56832 rows x 8 columns]

# %%
# newest trends

# Select only the columns you want to display


def top5_per_context():
    # First, ensure your DataFrame is sorted by last_updated in descending order
    df = transform_twitter_trend()
    df_sorted = df[['trend', 'domain_context', 'last_updated']]
    df_sorted = df_sorted.sort_values('last_updated', ascending=False)

    # Then, for each domain_context group, take the first 5 rows
    top5_per_context = df_sorted.groupby('domain_context').head(5).reset_index(drop=True)

    return top5_per_context

top5_per_context()
# Out:
# /Users/maria/Documents/NowTrending/frontend/transformation.py:96: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#                trend             domain_context               last_updated
# 0          Spartacus                   Politics 2025-02-06 01:17:40.900583
# 1             Druski  Trending in United States 2025-02-06 01:17:40.900583
# 2    Mitch McConnell                   Politics 2025-02-06 01:17:40.900583
# 3             Refund  Trending in United States 2025-02-06 01:17:40.900583
# 4            Hillary                   Politics 2025-02-06 01:17:40.900583
# ..               ...                        ...                        ...
# 537      El Salvador     Trending in Washington 2025-02-04 23:01:02.143000
# 538            Sanji                 Television 2025-02-04 23:00:13.811278
# 539     Marcus Smith                        NFL 2025-02-04 22:51:26.668849
# 540            Sanji                 Television 2025-02-04 22:51:25.312332
# 541            Sanji                 Television 2025-02-04 22:51:13.146986
#
# [542 rows x 3 columns]

# %%
df = transform_twitter_trend()
values = 'Trump'
filtered_df = df[df['trend'] == values]
filtered_df
# Out:
# /Users/maria/Documents/NowTrending/frontend/transformation.py:96: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#           id  trend  position meta_description domain_context  \
# 13142  13143  Trump        19      2.76M posts       Politics
# 13331  13332  Trump        19      2.76M posts       Politics
# 14177  14178  Trump         0       2.8M posts       Politics
# 16500  16501  Trump        19      3.66M posts       Politics
# 16888  16889  Trump        17      3.66M posts       Politics
# ...      ...    ...       ...              ...            ...
# 39326  39327  Trump        11      4.15M posts       Politics
# 39501  39502  Trump        10      4.15M posts       Politics
# 40238  40239  Trump        19      4.77M posts       Politics
# 41497  41498  Trump        19      5.28M posts       Politics
# 43952  43953  Trump        19      5.19M posts       Politics
#
#                                                      url  \
# 13142  twitter://search/?query=Trump&src=trend_click&...
# 13331  twitter://search/?query=Trump&src=trend_click&...
# 14177  twitter://search/?query=Trump&src=trend_click&...
# 16500  twitter://search/?query=Trump&src=trend_click&...
# 16888  twitter://search/?query=Trump&src=trend_click&...
# ...                                                  ...
# 39326  twitter://search/?query=Trump&src=trend_click&...
# 39501  twitter://search/?query=Trump&src=trend_click&...
# 40238  twitter://search/?query=Trump&src=trend_click&...
# 41497  twitter://search/?query=Trump&src=trend_click&...
# 43952  twitter://search/?query=Trump&src=trend_click&...
#
#                     last_updated           location_id
# 13142 2025-02-05 01:31:33.910106   6731622963572903665
# 13331 2025-02-05 01:31:59.511952   7825301456499146803
# 14177 2025-02-05 02:00:54.798498  -2152060852187384679
# 16500 2025-02-05 02:32:20.511772   -625131485298729454
# 16888 2025-02-05 02:33:03.060621  -7608764736147602991
# ...                          ...                   ...
# 39326 2025-02-05 14:30:24.422314   9063907876614026187
# 39501 2025-02-05 14:30:54.403220    149318359618127277
# 40238 2025-02-05 14:42:35.552761  -1021290998162208791
# 41497 2025-02-05 15:39:07.796791  -1769440319492945944
# 43952 2025-02-05 16:30:41.815642   1715201550013437228
#
# [73 rows x 8 columns]

# %%
def trend_growth():
    df = transform_twitter_trend()
    
    # Count occurrences of each trend
    trend_counts = df['trend'].value_counts()
    
    # Filter trends that appear more than 3 times
    valid_trends = trend_counts[trend_counts > 3].index
    
    # Filter the dataframe to keep only valid trends
    df_filtered = df[df['trend'].isin(valid_trends)]
    
    # Select relevant columns
    df_sorted = df_filtered[['trend', 'meta_description', 'last_updated']]
    
    return df_sorted
trend_growth()
# Out:
# /Users/maria/Documents/NowTrending/frontend/transformation.py:96: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#                 trend meta_description               last_updated
# 0      Fantastic Four                  2025-02-04 22:48:44.048739
# 1           Netanyahu                  2025-02-04 22:48:44.048739
# 2        Jessica Alba      2,054 posts 2025-02-04 22:48:44.048739
# 3                OSHA      37.9K posts 2025-02-04 22:48:44.048739
# 4        Waffle House      7,327 posts 2025-02-04 22:48:44.048739
# ...               ...              ...                        ...
# 58971  Jurassic World      81.9K posts 2025-02-06 01:33:16.724410
# 58972        Missouri      7,838 posts 2025-02-06 01:33:16.724410
# 58973         Kuminga      3,973 posts 2025-02-06 01:33:16.724410
# 58974    Jimmy Butler                  2025-02-06 01:33:16.724410
# 58975          Marina                  2025-02-06 01:33:16.724410
#
# [57537 rows x 3 columns]

# %%
df_loc = transform_google_locations()
df_loc
# Out:
# /Users/maria/Documents/NowTrending/frontend/transformation.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#     id         country
# 0    1   united states
# 1    2       argentina
# 2    3       australia
# 3    4         austria
# 4    5         belgium
# 5    6          brazil
# 6    7          canada
# 7    8           chile
# 8    9        colombia
# 9   10         czechia
# 10  11         denmark
# 11  12           egypt
# 12  13         finland
# 13  14          france
# 14  15         germany
# 15  16          greece
# 16  17       hong kong
# 17  18         hungary
# 18  19           india
# 19  20       indonesia
# 20  21         ireland
# 21  22          israel
# 22  23           italy
# 23  24           japan
# 24  25           kenya
# 25  26        malaysia
# 26  27          mexico
# 27  28     netherlands
# 28  29     new zealand
# 29  30         nigeria
# 30  31          norway
# 31  32     philippines
# 32  33          poland
# 33  34        portugal
# 34  35         romania
# 35  36          russia
# 36  37    saudi arabia
# 37  38       singapore
# 38  39    south africa
# 39  40     south korea
# 40  41          sweden
# 41  42     switzerland
# 42  43          taiwan
# 43  44        thailand
# 44  45          turkey
# 45  46         ukraine
# 46  47  united kingdom
# 47  48         vietnam

# %%
df_loc = transform_google_locations()
df_trend = transform_google_trend()
df_loc.rename(columns={'id':'google_location_id', 'country':'Country'}, inplace=True)
df_merged = pd.merge(df_loc, df_trend, on='google_location_id', how='inner')
df_merged.rename(columns={'trend':'Trend'}, inplace=True)
df_sorted = df_merged[['Trend', 'Country', 'last_updated']]
df_sorted
# Out:
# /Users/maria/Documents/NowTrending/frontend/transformation.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# /Users/maria/Documents/NowTrending/frontend/transformation.py:46: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#                        Trend        Country               last_updated
# 0                     Rfk Jr  united states 2025-02-05 11:38:31.868783
# 1                       Gaza  united states 2025-02-05 11:38:31.868783
# 2             Fantastic Four  united states 2025-02-05 11:38:31.868783
# 3              Marcus Jordan  united states 2025-02-05 11:38:31.868783
# 4                Tiger Woods  united states 2025-02-05 11:38:31.868783
# ...                      ...            ...                        ...
# 8654         Atletico Madrid        vietnam 2025-02-06 08:06:55.039871
# 8655    Cô Gái Rơi Khỏi Ô Tô        vietnam 2025-02-06 08:06:55.039871
# 8656      Alejandro Garnacho        vietnam 2025-02-06 08:06:55.039871
# 8657  Chiến Tranh Thương Mại        vietnam 2025-02-06 08:06:55.039871
# 8658            2 Ngày 1 Đêm        vietnam 2025-02-06 08:06:55.039871
#
# [8659 rows x 3 columns]

# %%
def google_loc():
    df_loc = transform_google_locations()
    df_trend = transform_google_trend()
    df_loc.rename(columns={'id':'google_location_id', 'country':'Country'}, inplace=True)
    df_merged = pd.merge(df_loc, df_trend, on='google_location_id', how='inner')
    df_merged.rename(columns={'trend':'Trend'}, inplace=True)
    df_sorted = df_merged[['Trend', 'Country', 'last_updated']]
    return df_sorted
